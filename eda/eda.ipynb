# %% [markdown]
# # 수집해야 하는 리소스 가격들
# * EC2
# -  NAT Gateway
# -  ELB
# -  EBS
# * EKS
# * RDS/Aurora
# * ElastiCache
# * MSK
# * EFS
# * S3
# * VPC

# %% [markdown]
# # 0. 관련 라이브러리 다운로드 및 모듈 불러오기

# %%
# !pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (2.2.3)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (from pandas) (2024.2)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in /Users/khj/Development/budget_template/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.8.30 charset-normalizer-3.3.2 idna-3.10 requests-2.32.3 urllib3-2.2.3

# %%
import pandas as pd
import json
import requests
import datetime
from pprint import pprint

# %%
pd.set_option("display.max_colwidth", 100)

# %% [markdown]
# # 1. AWS 가격정보 수집

# %%
def download_resource_price_json(resource: str, region: str):
    request_template = "https://pricing.us-east-1.amazonaws.com/offers/v1.0/aws/{resource}/current/{region}/index.json"
    url = request_template.format(resource=resource, region=region)
    response = requests.get(url)
    today = datetime.date.today().isoformat()
    with open(f"{resource}_{today}.json", "w") as f:
        f.write(response.text)

def download_prices(resources: list[str], region: str):
    for resource in resources:
        download_resource_price_json(resource, region)

# %%
download_resource_price_json("AmazonS3", "ap-northeast-2")
# "TimedStorage",

# %%
# 수집대상 리소스
resources = ["AmazonEC2", "AmazonRDS", "AmazonVPC", "AmazonMSK", "AmazonElastiCache"]
download_prices(resources, "ap-northeast-2")

# %% [markdown]
# # 2. 가격정보 전처리

# %% [markdown]
# ## 2-1. EC2 가격정보 전처리 (EC2, NAT Gateway, ELB, EBS)

# %%
with open("AmazonEC2_2024-10-03.json", "r") as f:
    raw_ec2_price_data = json.load(f)

# %%
def flatten_price(data: dict, product_family: str):
    result = []
    
    price_data = data["terms"]["OnDemand"]
    
    for sku, value in data["products"].items():
        new_row = value["attributes"]
        if value.get("productFamily") != product_family:
            continue
        
        # 딕셔너리의 첫번째 값만 가져옴
        price_data_row = next(iter(price_data[sku].values()))
        # 딕셔너리의 첫번째 값만 가져옴
        price_data_row = next(iter(price_data_row["priceDimensions"].values()))
        new_row["description"] = price_data_row["description"]
        new_row["pricePerUnit"] = price_data_row["pricePerUnit"]["USD"]
        new_row["unit"] = price_data_row["unit"]
        result.append(new_row)

    return pd.DataFrame(result)

# %%
def filter_df(df: pd.DataFrame, filters: dict):
    for column, value in filters.items():
        if column not in df.columns:
            raise KeyError(f"데이터프레임에 '{column}' 컬럼이 존재하지 않습니다.")
        if isinstance(value, list):
            df = df[df[column].isin(value)]
        else:
            df = df[df[column] == value]
    return df

# %%
ec2_df = flatten_price(raw_ec2_price_data, "Compute Instance")

ec2_filters = {
    "operatingSystem": ["Linux", "Windows"],
    "tenancy": "Shared",
    "currentGeneration": "Yes",
    "preInstalledSw": "NA",
    "storage": "EBS only",
    "processorArchitecture": "64-bit",
    "capacitystatus": "Used",
    "marketoption": "OnDemand",
}
# ec2_columns = [
#     "instanceType",
#     "instanceFamily",
#     "vcpu",
#     "memory",
#     "gpuMemory",
#     "operatingSystem",
#     "physicalProcessor",
#     "pricePerUnit",
#     "unit",
# ]

ec2_df = filter_df(ec2_df, ec2_filters)
# 필터링된 컬럼만 선택
# ec2_df = ec2_df[ec2_columns]
# 중복된 행 제거
ec2_df.drop_duplicates(subset=["instanceType", "pricePerUnit"])
# Out:
#       servicecode              location locationType  instanceType  \
# 29      AmazonEC2  Asia Pacific (Seoul)   AWS Region  c7i.12xlarge
# 70      AmazonEC2  Asia Pacific (Seoul)   AWS Region    r5.4xlarge
# 219     AmazonEC2  Asia Pacific (Seoul)   AWS Region    g3s.xlarge
# 228     AmazonEC2  Asia Pacific (Seoul)   AWS Region  r6i.16xlarge
# 249     AmazonEC2  Asia Pacific (Seoul)   AWS Region    m6i.xlarge
# ...           ...                   ...          ...           ...
# 39240   AmazonEC2  Asia Pacific (Seoul)   AWS Region     p2.xlarge
# 39266   AmazonEC2  Asia Pacific (Seoul)   AWS Region    m6i.xlarge
# 39397   AmazonEC2  Asia Pacific (Seoul)   AWS Region    r5.4xlarge
# 39425   AmazonEC2  Asia Pacific (Seoul)   AWS Region   inf1.xlarge
# 39596   AmazonEC2  Asia Pacific (Seoul)   AWS Region   r6i.4xlarge
#
#       currentGeneration                   instanceFamily vcpu  \
# 29                  Yes                Compute optimized   48
# 70                  Yes                 Memory optimized   16
# 219                 Yes                     GPU instance    4
# 228                 Yes                 Memory optimized   64
# 249                 Yes                  General purpose    4
# ...                 ...                              ...  ...
# 39240               Yes                     GPU instance    4
# 39266               Yes                  General purpose    4
# 39397               Yes                 Memory optimized   16
# 39425               Yes  Machine Learning ASIC Instances    4
# 39596               Yes                 Memory optimized   16
#
#                                physicalProcessor clockSpeed    memory  ...  \
# 29         Intel Xeon Scalable (Sapphire Rapids)    3.2 GHz    96 GiB  ...
# 70                      Intel Xeon Platinum 8175    3.1 GHz   128 GiB  ...
# 219            Intel Xeon E5-2686 v4 (Broadwell)    2.3 GHz  30.5 GiB  ...
# 228                  Intel Xeon 8375C (Ice Lake)    3.5 GHz   512 GiB  ...
# 249                  Intel Xeon 8375C (Ice Lake)    3.5 GHz    16 GiB  ...
# ...                                          ...        ...       ...  ...
# 39240          Intel Xeon E5-2686 v4 (Broadwell)    2.3 GHz    61 GiB  ...
# 39266                Intel Xeon 8375C (Ice Lake)    3.5 GHz    16 GiB  ...
# 39397                   Intel Xeon Platinum 8175    3.1 GHz   128 GiB  ...
# 39425  Intel Xeon Platinum 8275CL (Cascade Lake)        NaN     8 GiB  ...
# 39596                Intel Xeon 8375C (Ice Lake)    3.5 GHz   128 GiB  ...
#
#       normalizationSizeFactor preInstalledSw  \
# 29                         96             NA
# 70                         32             NA
# 219                         8             NA
# 228                       128             NA
# 249                         8             NA
# ...                       ...            ...
# 39240                       8             NA
# 39266                       8             NA
# 39397                      32             NA
# 39425                      NA             NA
# 39596                      32             NA
#
#                                                  processorFeatures  \
# 29     Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo; Intel AMX
# 70                Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
# 219                                                            NaN
# 228               Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
# 249               Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
# ...                                                            ...
# 39240                           Intel AVX; Intel AVX2; Intel Turbo
# 39266             Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
# 39397             Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
# 39425                                                          NaN
# 39596             Intel AVX; Intel AVX2; Intel AVX512; Intel Turbo
#
#            regionCode                   servicename vpcnetworkingsupport  \
# 29     ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 70     ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 219    ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 228    ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 249    ap-northeast-2  Amazon Elastic Compute Cloud                 true
# ...               ...                           ...                  ...
# 39240  ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 39266  ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 39397  ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 39425  ap-northeast-2  Amazon Elastic Compute Cloud                 true
# 39596  ap-northeast-2  Amazon Elastic Compute Cloud                 true
#
#                                                       description  \
# 29         $2.4192 per On Demand Linux c7i.12xlarge Instance Hour
# 70     $1.216 per On Demand Windows BYOL r5.4xlarge Instance Hour
# 219         $1.118 per On Demand Windows g3s.xlarge Instance Hour
# 228         $4.864 per On Demand Linux r6i.16xlarge Instance Hour
# 249           $0.236 per On Demand Linux m6i.xlarge Instance Hour
# ...                                                           ...
# 39240        $1.649 per On Demand Windows p2.xlarge Instance Hour
# 39266        $0.42 per On Demand Windows m6i.xlarge Instance Hour
# 39397       $1.952 per On Demand Windows r5.4xlarge Instance Hour
# 39425        $0.281 per On Demand Linux inf1.xlarge Instance Hour
# 39596      $1.952 per On Demand Windows r6i.4xlarge Instance Hour
#
#        pricePerUnit unit  gpu
# 29     2.4192000000  Hrs  NaN
# 70     1.2160000000  Hrs  NaN
# 219    1.1180000000  Hrs    1
# 228    4.8640000000  Hrs  NaN
# 249    0.2360000000  Hrs  NaN
# ...             ...  ...  ...
# 39240  1.6490000000  Hrs    1
# 39266  0.4200000000  Hrs  NaN
# 39397  1.9520000000  Hrs  NaN
# 39425  0.2810000000  Hrs  NaN
# 39596  1.9520000000  Hrs  NaN
#
# [442 rows x 40 columns]

# %%
ec2_df.dtypes
# Out:
# servicecode                    object
# location                       object
# locationType                   object
# instanceType                   object
# currentGeneration              object
# instanceFamily                 object
# vcpu                           object
# physicalProcessor              object
# clockSpeed                     object
# memory                         object
# storage                        object
# networkPerformance             object
# processorArchitecture          object
# tenancy                        object
# operatingSystem                object
# licenseModel                   object
# usagetype                      object
# operation                      object
# availabilityzone               object
# capacitystatus                 object
# classicnetworkingsupport       object
# dedicatedEbsThroughput         object
# ecu                            object
# enhancedNetworkingSupported    object
# gpuMemory                      object
# instancesku                    object
# intelAvxAvailable              object
# intelAvx2Available             object
# intelTurboAvailable            object
# marketoption                   object
# normalizationSizeFactor        object
# preInstalledSw                 object
# processorFeatures              object
# regionCode                     object
# servicename                    object
# vpcnetworkingsupport           object
# description                    object
# pricePerUnit                   object
# unit                           object
# gpu                            object
# dtype: object

# %%
# EBS 가격정보 dataframe으로 변환

ebs_df = flatten_price(raw_ec2_price_data, "Storage")
ebs_filters = {
    "volumeApiName": ["gp2", "gp3"],
}
ebs_df = filter_df(ebs_df, ebs_filters)

# %%
ebs_df
# Out:
#   servicecode              location locationType storageMedia  \
# 0   AmazonEC2  Asia Pacific (Seoul)   AWS Region   SSD-backed
# 5   AmazonEC2  Asia Pacific (Seoul)   AWS Region   SSD-backed
#
#         volumeType maxVolumeSize maxIopsvolume maxThroughputvolume  \
# 0  General Purpose        16 TiB         16000          1000 MiB/s
# 5  General Purpose        16 TiB         16000           250 MiB/s
#
#                   usagetype operation      regionCode  \
# 0  APN2-EBS:VolumeUsage.gp3            ap-northeast-2
# 5  APN2-EBS:VolumeUsage.gp2            ap-northeast-2
#
#                     servicename volumeApiName  \
# 0  Amazon Elastic Compute Cloud           gp3
# 5  Amazon Elastic Compute Cloud           gp2
#
#                                                                                    description  \
# 0     $0.0912 per GB-month of General Purpose (gp3) provisioned storage - Asia Pacific (Seoul)
# 5  $0.114 per GB-month of General Purpose SSD (gp2) provisioned storage - Asia Pacific (Seoul)
#
#    pricePerUnit   unit    maxIopsBurstPerformance
# 0  0.0912000000  GB-Mo                        NaN
# 5  0.1140000000  GB-Mo  3000 for volumes <= 1 TiB

# %%
# Load Balancer 가격정보 dataframe으로 변환
alb_df = flatten_price(raw_ec2_price_data, "Load Balancer-Application")
alb_filters = {"usagetype": "APN2-LoadBalancerUsage"}
alb_df = filter_df(alb_df, alb_filters)
alb_df
# Out:
#   servicecode              location locationType         group  \
# 0   AmazonEC2  Asia Pacific (Seoul)   AWS Region  ELB:Balancer
#
#                                          groupDescription  \
# 0  LoadBalancer hourly usage by Application Load Balancer
#
#                 usagetype                  operation      regionCode  \
# 0  APN2-LoadBalancerUsage  LoadBalancing:Application  ap-northeast-2
#
#                     servicename  \
# 0  Amazon Elastic Compute Cloud
#
#                                                    description  pricePerUnit  \
# 0  $0.0225 per Application LoadBalancer-hour (or partial hour)  0.0225000000
#
#   unit
# 0  Hrs

# %%
nlb_df = flatten_price(raw_ec2_price_data, "Load Balancer-Network")
nlb_filters = {"usagetype": "APN2-LoadBalancerUsage"}
nlb_df = filter_df(nlb_df, nlb_filters)
nlb_df
# Out:
#   servicecode              location locationType         group  \
# 0   AmazonEC2  Asia Pacific (Seoul)   AWS Region  ELB:Balancer
#
#                                      groupDescription               usagetype  \
# 0  LoadBalancer hourly usage by Network Load Balancer  APN2-LoadBalancerUsage
#
#                operation      regionCode                   servicename  \
# 0  LoadBalancing:Network  ap-northeast-2  Amazon Elastic Compute Cloud
#
#                                                description  pricePerUnit unit
# 0  $0.0225 per Network LoadBalancer-hour (or partial hour)  0.0225000000  Hrs

# %%
nat_df = flatten_price(raw_ec2_price_data, "NAT Gateway")
nat_df
# Out:
#   servicecode              location locationType           group  \
# 0   AmazonEC2  Asia Pacific (Seoul)   AWS Region  NGW:NatGateway
# 1   AmazonEC2  Asia Pacific (Seoul)   AWS Region  NGW:NatGateway
#
#                                   groupDescription              usagetype  \
# 0  Charge for per GB data processed by NatGateways  APN2-NatGateway-Bytes
# 1                   Hourly charge for NAT Gateways  APN2-NatGateway-Hours
#
#     operation      regionCode                   servicename  \
# 0  NatGateway  ap-northeast-2  Amazon Elastic Compute Cloud
# 1  NatGateway  ap-northeast-2  Amazon Elastic Compute Cloud
#
#                                     description  pricePerUnit unit
# 0  $0.059 per GB Data Processed by NAT Gateways  0.0590000000   GB
# 1                   $0.059 per NAT Gateway Hour  0.0590000000  Hrs

# %%
nat_filter = {
    "unit": "Hrs",
    "usagetype": "APN2-NatGateway-Hours",
}
nat_df = filter_df(nat_df, nat_filter)

# %%
nat_df
# Out:
#   servicecode              location locationType           group  \
# 1   AmazonEC2  Asia Pacific (Seoul)   AWS Region  NGW:NatGateway
#
#                  groupDescription              usagetype   operation  \
# 1  Hourly charge for NAT Gateways  APN2-NatGateway-Hours  NatGateway
#
#        regionCode                   servicename                  description  \
# 1  ap-northeast-2  Amazon Elastic Compute Cloud  $0.059 per NAT Gateway Hour
#
#    pricePerUnit unit
# 1  0.0590000000  Hrs

# %% [markdown]
# ## 2-2. RDS/Aurora 가격정보 전처리

# %%
with open("AmazonRDS_2024-10-03.json", "r") as f:
    raw_rds_price_data = json.load(f)

# %%
rds_df = flatten_price(raw_rds_price_data, "Database Instance")
rds_filters = {
    "deploymentOption": "Single-AZ",
    "locationType": "AWS Region",
    "currentGeneration": "Yes",
}
rds_df = filter_df(rds_df, rds_filters)

# %%
rds_df
# Out:
#      servicecode              location locationType  \
# 0      AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 5      AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 10     AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 11     AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 14     AmazonRDS  Asia Pacific (Seoul)   AWS Region
# ...          ...                   ...          ...
# 2632   AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 2633   AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 2635   AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 2636   AmazonRDS  Asia Pacific (Seoul)   AWS Region
# 2637   AmazonRDS  Asia Pacific (Seoul)   AWS Region
#
#                    instanceType currentGeneration    instanceFamily vcpu  \
# 0     db.r5b.2xlarge.tpc1.mem2x               Yes  Memory optimized    8
# 5                  db.r5b.large               Yes  Memory optimized    2
# 10             db.m6gd.16xlarge               Yes   General purpose   64
# 11               db.r6i.8xlarge               Yes  Memory optimized   32
# 14                db.r5.8xlarge               Yes  Memory optimized   32
# ...                         ...               ...               ...  ...
# 2632  db.r5b.8xlarge.tpc2.mem3x               Yes  Memory optimized   32
# 2633              db.r5.8xlarge               Yes  Memory optimized   32
# 2635          db.x2idn.24xlarge               Yes  Memory optimized   96
# 2636             db.m6g.4xlarge               Yes   General purpose   16
# 2637             db.r5d.4xlarge               Yes  Memory optimized   16
#
#                     physicalProcessor    memory                      storage  \
# 0     Intel Xeon Platinum 8000 series   128 GiB                     EBS Only
# 5     Intel Xeon Platinum 8000 series    16 GiB                     EBS Only
# 10                      AWS Graviton2   256 GiB            2 x 1900 NVMe SSD
# 11       Intel Xeon Scalable Ice Lake   256 GiB                     EBS Only
# 14           Intel Xeon Platinum 8175   256 GiB  Aurora IO Optimization Mode
# ...                               ...       ...                          ...
# 2632  Intel Xeon Platinum 8000 series   768 GiB                     EBS Only
# 2633         Intel Xeon Platinum 8175   256 GiB                     EBS Only
# 2635     Intel Xeon Scalable Ice Lake  1536 GiB            2 x 1425 NVMe SSD
# 2636                    AWS Graviton2    64 GiB                     EBS Only
# 2637         Intel Xeon Platinum 8175   128 GiB             2 x 300 NVMe SSD
#
#       ...                         servicename  \
# 0     ...  Amazon Relational Database Service
# 5     ...  Amazon Relational Database Service
# 10    ...  Amazon Relational Database Service
# 11    ...  Amazon Relational Database Service
# 14    ...  Amazon Relational Database Service
# ...   ...                                 ...
# 2632  ...  Amazon Relational Database Service
# 2633  ...  Amazon Relational Database Service
# 2635  ...  Amazon Relational Database Service
# 2636  ...  Amazon Relational Database Service
# 2637  ...  Amazon Relational Database Service
#
#                                             description   pricePerUnit unit  \
# 0     USD 2.634 per RDS db.r5b.2xlarge.tpc1.mem2x Si...   2.6340000000  Hrs
# 5     USD 0.329 per RDS db.r5b.large Single-AZ insta...   0.3290000000  Hrs
# 10    $ 8.352 per RDS db.m6gd.16xlarge Single-AZ ins...   8.3520000000  Hrs
# 11    USD 4.432 per RDS db.r6i.8xlarge Single-AZ ins...   4.4320000000  Hrs
# 14    $7.2800 per RDS db.r5.8xlarge IO-optimized Sin...   7.2800000000  Hrs
# ...                                                 ...            ...  ...
# 2632  USD 15.806 per RDS db.r5b.8xlarge.tpc2.mem3x S...  15.8060000000  Hrs
# 2633  $ 4.56 per RDS db.r5.8xlarge Single-AZ instanc...   4.5600000000  Hrs
# 2635  $ 24.384 per RDS db.x2idn.24xlarge Single-AZ i...  24.3840000000  Hrs
# 2636  $ 1.678 per RDS db.m6g.4xlarge Single-AZ insta...   1.6780000000  Hrs
# 2637  $ 2.732 per RDS db.r5d.4xlarge Single-AZ insta...   2.7320000000  Hrs
#
#      deploymentModel     clockSpeed dedicatedEbsThroughput  \
# 0                NaN            NaN                    NaN
# 5                NaN  Up to 3.1 GHz               156 Mbps
# 10               NaN            NaN                    NaN
# 11               NaN            NaN                    NaN
# 14               NaN            NaN                    NaN
# ...              ...            ...                    ...
# 2632             NaN            NaN                    NaN
# 2633             NaN            NaN                    NaN
# 2635             NaN            NaN                    NaN
# 2636             NaN            NaN                    NaN
# 2637             NaN            NaN                    NaN
#
#      enhancedNetworkingSupported processorFeatures pricingUnit
# 0                            NaN               NaN         NaN
# 5                            Yes               NaN         NaN
# 10                           NaN               NaN         NaN
# 11                           NaN               NaN         NaN
# 14                           NaN               NaN         NaN
# ...                          ...               ...         ...
# 2632                         NaN               NaN         NaN
# 2633                         NaN               NaN         NaN
# 2635                         NaN               NaN         NaN
# 2636                         NaN               NaN         NaN
# 2637                         NaN               NaN         NaN
#
# [904 rows x 33 columns]

# %%
rds_df = rds_df.drop_duplicates(subset=["instanceType", "pricePerUnit"])
rds_columns = [
    "servicecode", 
    "instanceType",
    "databaseEngine",
    "vcpu",
    "memory",
    "pricePerUnit",
    "unit",
]
rds_df = rds_df[rds_columns]
rds_df
# Out:
#      servicecode               instanceType databaseEngine vcpu    memory  \
# 0      AmazonRDS  db.r5b.2xlarge.tpc1.mem2x         Oracle    8   128 GiB
# 5      AmazonRDS               db.r5b.large         Oracle    2    16 GiB
# 10     AmazonRDS           db.m6gd.16xlarge     PostgreSQL   64   256 GiB
# 11     AmazonRDS             db.r6i.8xlarge         Oracle   32   256 GiB
# 14     AmazonRDS              db.r5.8xlarge   Aurora MySQL   32   256 GiB
# ...          ...                        ...            ...  ...       ...
# 2604   AmazonRDS              db.t3.2xlarge     SQL Server    8    32 GiB
# 2612   AmazonRDS             db.m6g.2xlarge          MySQL    8    32 GiB
# 2624   AmazonRDS              db.m5.2xlarge     SQL Server    8    32 GiB
# 2632   AmazonRDS  db.r5b.8xlarge.tpc2.mem3x         Oracle   32   768 GiB
# 2635   AmazonRDS          db.x2idn.24xlarge         Oracle   96  1536 GiB
#
#        pricePerUnit unit
# 0      2.6340000000  Hrs
# 5      0.3290000000  Hrs
# 10     8.3520000000  Hrs
# 11     4.4320000000  Hrs
# 14     7.2800000000  Hrs
# ...             ...  ...
# 2604   4.6320000000  Hrs
# 2612   0.8390000000  Hrs
# 2624   2.7230000000  Hrs
# 2632  15.8060000000  Hrs
# 2635  24.3840000000  Hrs
#
# [551 rows x 7 columns]

# %%
rds_df.head()
# Out:
#                  instanceType databaseEngine vcpu   memory  pricePerUnit unit
# 0   db.r5b.2xlarge.tpc1.mem2x         Oracle    8  128 GiB  2.6340000000  Hrs
# 5                db.r5b.large         Oracle    2   16 GiB  0.3290000000  Hrs
# 10           db.m6gd.16xlarge     PostgreSQL   64  256 GiB  8.3520000000  Hrs
# 11             db.r6i.8xlarge         Oracle   32  256 GiB  4.4320000000  Hrs
# 14              db.r5.8xlarge   Aurora MySQL   32  256 GiB  7.2800000000  Hrs

# %%
len(rds_df)
# Out:
# 551

# %% [markdown]
# ## 2-3. EKS 가격정보 전처리

# %%
with open("AmazonEKS_2024-10-03.json", "r") as f:
    raw_eks_price_data = json.load(f)

# %%
eks_df = flatten_price(raw_eks_price_data, "Compute")
eks_filters = {
    "locationType": "AWS Region",
    "usagetype": "APN2-AmazonEKS-Hours:perCluster",
    
}
eks_df = filter_df(eks_df, eks_filters)

# %%
eks_df
# Out:
#   servicecode              location locationType  \
# 2   AmazonEKS  Asia Pacific (Seoul)   AWS Region
#
#                          usagetype        operation      regionCode  \
# 2  APN2-AmazonEKS-Hours:perCluster  CreateOperation  ap-northeast-2
#
#                                        servicename storagetype  \
# 2  Amazon Elastic Container Service for Kubernetes         NaN
#
#                                       description  pricePerUnit   unit  \
# 2  Amazon EKS local cluster usage on AWS Outposts  0.1000000000  hours
#
#   tenancy memorytype    tiertype cputype
# 2     NaN        NaN  HAStandard     NaN

# %% [markdown]
# ## 2-4. ElastiCache 가격정보 전처리

# %%
with open("AmazonElastiCache_2024-10-03.json", "r") as f:
    raw_redis_price_data = json.load(f)

# %%
redis_df = flatten_price(raw_redis_price_data, "Cache Instance")
redis_filters = {
    "locationType": "AWS Region",
    "currentGeneration": "Yes",
}
redis_df = filter_df(redis_df, redis_filters)

# %%
len(redis_df)
# Out:
# 120

# %%
redis_df = redis_df.drop_duplicates(subset=["instanceType", "pricePerUnit"])
# redis_columns = [
#     "servicecode", 
#     "instanceType",
#     "cacheEngine",
#     "vcpu",
#     "memory",
#     "pricePerUnit",
#     "unit",
# ]
# redis_df = redis_df[redis_columns]

# %%
redis_df.head()
# Out:
#           servicecode              location locationType       instanceType  \
# 1   AmazonElastiCache  Asia Pacific (Seoul)   AWS Region  cache.m7g.4xlarge
# 2   AmazonElastiCache  Asia Pacific (Seoul)   AWS Region     cache.t2.small
# 6   AmazonElastiCache  Asia Pacific (Seoul)   AWS Region   cache.m5.2xlarge
# 7   AmazonElastiCache  Asia Pacific (Seoul)   AWS Region   cache.r4.2xlarge
# 10  AmazonElastiCache  Asia Pacific (Seoul)   AWS Region    cache.r5.xlarge
#
#    currentGeneration    instanceFamily vcpu     memory networkPerformance  \
# 1                Yes          Standard   16  52.26 GiB   Up to 15 Gigabit
# 2                Yes          Standard    1   1.55 GiB    Low to Moderate
# 6                Yes          Standard    8  26.04 GiB   Up to 10 Gigabit
# 7                Yes  Memory optimized    8  50.47 GiB   Up to 10 Gigabit
# 10               Yes  Memory optimized    4  26.32 GiB   Up to 10 Gigabit
#
#    cacheEngine                         usagetype                operation  \
# 1        Redis  APN2-NodeUsage:cache.m7g.4xlarge  CreateCacheCluster:0002
# 2        Redis     APN2-NodeUsage:cache.t2.small  CreateCacheCluster:0002
# 6        Redis   APN2-NodeUsage:cache.m5.2xlarge  CreateCacheCluster:0002
# 7    Memcached   APN2-NodeUsage:cache.r4.2xlarge  CreateCacheCluster:0001
# 10   Memcached    APN2-NodeUsage:cache.r5.xlarge  CreateCacheCluster:0001
#
#         regionCode         servicename  \
# 1   ap-northeast-2  Amazon ElastiCache
# 2   ap-northeast-2  Amazon ElastiCache
# 6   ap-northeast-2  Amazon ElastiCache
# 7   ap-northeast-2  Amazon ElastiCache
# 10  ap-northeast-2  Amazon ElastiCache
#
#                                                                description  \
# 1                $1.54 per Gen Purpose m7g.4xlarge node hour running Redis
# 2      $0.052 per T2 Small Cache node-hour (or partial hour) running Redis
# 6                $0.765 per Gen Purpose M5.2xlarge node hour running Redis
# 7   $1.092 per Enhanced High memory R4.2xlarge node hour running Memcached
# 10   $0.517 per Enhanced High memory R5.xlarge node hour running Memcached
#
#     pricePerUnit unit
# 1   1.5400000000  Hrs
# 2   0.0520000000  Hrs
# 6   0.7650000000  Hrs
# 7   1.0920000000  Hrs
# 10  0.5170000000  Hrs

# %% [markdown]
# ## 2-5 S3 가격정보 전처리

# %%
with open("AmazonS3_2024-10-03.json", "r") as f:
    raw_s3_price_data = json.load(f)

# %%
s3_df = flatten_price(raw_s3_price_data, "Storage")
s3_filters = {
    # "availability": ["99.99%", "99.9%", "99.5%"]
    "storageClass": [
        "General Purpose",
        "Infrequent Access",
        "Archive Instant Retrieval",
    ]
}
s3_df = filter_df(s3_df, s3_filters)

# %%
s3_df
# Out:
#    servicecode              location locationType availability  \
# 6     AmazonS3  Asia Pacific (Seoul)   AWS Region       99.99%
# 8     AmazonS3  Asia Pacific (Seoul)   AWS Region        99.9%
# 10    AmazonS3  Asia Pacific (Seoul)   AWS Region        99.9%
# 14    AmazonS3  Asia Pacific (Seoul)   AWS Region        99.5%
#
#                  storageClass                    volumeType  \
# 6             General Purpose                      Standard
# 8           Infrequent Access  Standard - Infrequent Access
# 10  Archive Instant Retrieval     Glacier Instant Retrieval
# 14          Infrequent Access  One Zone - Infrequent Access
#
#                         usagetype operation     durability      regionCode  \
# 6       APN2-TimedStorage-ByteHrs            99.999999999%  ap-northeast-2
# 8   APN2-TimedStorage-SIA-ByteHrs            99.999999999%  ap-northeast-2
# 10  APN2-TimedStorage-GIR-ByteHrs            99.999999999%  ap-northeast-2
# 14  APN2-TimedStorage-ZIA-ByteHrs            99.999999999%  ap-northeast-2
#
#                       servicename  \
# 6   Amazon Simple Storage Service
# 8   Amazon Simple Storage Service
# 10  Amazon Simple Storage Service
# 14  Amazon Simple Storage Service
#
#                                                            description  \
# 6                  $0.025 per GB - first 50 TB / month of storage used
# 8   $0.0138 per GB-Month of storage used in Standard-Infrequent Access
# 10    $0.005 per GB-Month of storage used in Glacier Instant Retrieval
# 14   $0.011 per GB-Month of storage used in One Zone-Infrequent Access
#
#     pricePerUnit   unit overhead
# 6   0.0250000000  GB-Mo      NaN
# 8   0.0138000000  GB-Mo      NaN
# 10  0.0050000000  GB-Mo      NaN
# 14  0.0110000000  GB-Mo      NaN

# %% [markdown]
# 데이터 처리 과정
#
# 1. 가격 파일 엑셀로 다운로드 (다운받을 리소스는 환경변수로 관리)
# 2. json 파일로 오픈
# 3. dataframe 변환 (flatten_price)
# 4. 필터링 (filter_df, 필터할 요소는 따로 yaml로 관리?)

# %% [markdown]
# # 3. 데이터 저장
#
# * dynamoDB에 데이터 저장
# * version (날짜) 확인해서 저장
